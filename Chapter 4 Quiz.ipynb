# %%
1.
Question 1
Which Python keyword indicates the start of a function definition?

1 point

return


def


continue


rad

2.
Question 2
In Python, how do you indicate the end of the block of code that makes up the function?

1 point

You de-indent a line of code to the same indent level as the def keyword


You add a line that has at least 10 dashes


You put the colon character (:) in the first column of a line


You add the matching curly brace that was used to start the function }

3.
Question 3
In Python what is the input() feature best described as?

1 point

A reserved word


A user-defined function


A built-in function


A data structure that can hold multiple values using strings as keys

4.
Question 4
What does the following code print out?

1234
def thing():
    print('Hello')

print('There')

1 point

Hello


There


def

thing


thing

Hello

There

5.
Question 5
In the following Python code, which of the following is an "argument" to a function?

123
x = 'banana'
y = max(x)
z = y * 2

1 point

x


max


'banana'


y

6.
Question 6
What will the following Python code print out?

12345
def func(x) :
    print(x)

func(10)
func(20)

1 point

10

20


x

10

x

20


x

20


func

func

7.
Question 7
Which line of the following Python program will never execute?

123456
def stuff():
    print('Hello')
    return
    print('World')

stuff()

1 point

print ('World')


return


print('Hello')


def stuff():


stuff()

8.
Question 8
What will the following Python program print out?

123456789
def greet(lang):
    if lang == 'es':
        return 'Hola'
    elif lang == 'fr':
        return 'Bonjour'
    else:
        return 'Hello'

print(greet('fr'),'Michael')

1 point

Bonjour Michael


Hola Michael


Hello Michael


def

Hola

Bonjour

Hello

Michael

9.
Question 9
What does the following Python code print out? (Note that this is a bit of a trick question and the code has what many would consider to be a flaw/bug - so read carefully).

123456
def addtwo(a, b):
    added = a + b
    return a

x = addtwo(2, 7)
print(x)

1 point

2


9


14


7

10.
Question 10
What is the most important benefit of writing your own functions?

1 point

Following the rule that whenever a program is more than 10 lines you must use a function


To avoid having more than 10 lines of sequential code without an indent or de-indent


Following the rule that no function can have more than 10 statements in it


Avoiding writing the same non-trivial code more than once in your program

# %%
1. Question 1:
   - **Correct Answer:** def

2. Question 2:
   - **Correct Answer:** You de-indent a line of code to the same indent level as the def keyword

3. Question 3:
   - **Correct Answer:** A built-in function

4. Question 4:
   - **Correct Answer:** There

5. Question 5:
   - **Correct Answer:** x

6. Question 6:
   - **Correct Answer:** 10, 20

7. Question 7:
   - **Correct Answer:** print('World')

8. Question 8:
   - **Correct Answer:** Bonjour Michael

9. Question 9:
   - **Correct Answer:** 2

10. Question 10:
    - **Correct Answer:** Avoiding writing the same non-trivial code more than once in your program
